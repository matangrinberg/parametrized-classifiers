# %% [markdown]
# # Data prepration

# %%
import numpy as np
import datetime
import os
import sklearn.metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from scipy.stats import chi
from scipy import stats

# %%
############
# Functions
############

# Generate n data for set of thetas
def generate_data(n, thetas, amps, rand=1234):
    m1 = np.zeros(n)
    v1 = np.ones(n)
    m2 = mean_gen(thetas)
    v2 = var_gen(thetas)
    
    x1, y1 = np.transpose(np.array([amps * np.random.normal(m1, v1, size=n), thetas, amps])), np.zeros(n)
    x2, y2 = np.transpose(np.array([amps * np.random.normal(m2, v2, size=n), thetas, amps])), np.ones(n)
    x, y = np.append(x1, x2, axis=0), np.append(y1, y2, axis=0)
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = rand)
    
    return x_train, x_test, y_train, y_test

def mean_gen(theta):
    mu = 0.5 - (np.sqrt(2)/2) * np.cos(theta + np.pi / 4)
    return mu

def var_gen(theta):
    v = 1.5 - (np.sqrt(2)/2) * np.sin(theta + np.pi / 4)
    return v

def discrete_thetas(n, m):
    xk = np.arange(m)
    pk = (1 / m) * np.ones(int(m))
    discrete_distr = stats.rv_discrete(name='discrete_distr', values=(xk, pk))
    thetas = discrete_distr.rvs(size=n) / (m / 6)
    return thetas

# %%
# Uniform Distribution of Thetas
n = 100000
rand_n = 1234
thetas = np.random.uniform(0, 2 * np.pi, n)
amps = np.random.uniform(0, 2, n)


x_train, x_test, y_train, y_test = generate_data(n, thetas, amps, rand_n)

# %%
# Discrete Distribution of Thetas
# m = 3
# thetas = discrete_thetas(n, m)
# x_train, x_test, y_train, y_test = theta_data(n, thetas, rand_n)

# %% [markdown]
# # Training Interpolated Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
]);

loss_fn = tf.keras.losses.BinaryCrossentropy()
model.compile(
    optimizer='adam',
    loss=loss_fn,
    metrics=['accuracy']
)

batch_size = 1000

checkpoint_path = "tutorial/checkpoints/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    verbose=1,
    save_freq=10*batch_size
)

log_dir = "tutorial/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

EPOCHS=10
model.fit(
    x_train, y_train, epochs=EPOCHS,
    batch_size=batch_size,
    callbacks=[cp_callback, tensorboard_callback]
);

model.save('3dmodels/interpolated_model_cont')
# Out:
# 2022-06-30 14:35:17.192828: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-30 14:35:17.192868: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-30 14:35:17.192898: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyter-matan): /proc/driver/nvidia/version does not exist
# 2022-06-30 14:35:17.193347: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-30 14:35:17.214751: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-06-30 14:35:17.214790: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-06-30 14:35:17.218174: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-06-30 14:35:17.498878: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
#  11/160 [=>............................] - ETA: 2s - loss: 0.6860 - accuracy: 0.5482
# 2022-06-30 14:35:18.086453: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-06-30 14:35:18.086490: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-06-30 14:35:18.097528: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-06-30 14:35:18.104448: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-06-30 14:35:18.133592: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18
#
# 2022-06-30 14:35:18.140256: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.trace.json.gz
# 2022-06-30 14:35:18.159020: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18
#
# 2022-06-30 14:35:18.163651: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.memory_profile.json.gz
# 2022-06-30 14:35:18.184374: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18
# Dumped tool data for xplane.pb to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.xplane.pb
# Dumped tool data for overview_page.pb to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.overview_page.pb
# Dumped tool data for input_pipeline.pb to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to tutorial/logs/20220630-143517/train/plugins/profile/2022_06_30_14_35_18/jupyter-matan.kernel_stats.pb
# 160/160 [==============================] - 2s 6ms/step - loss: 0.6476 - accuracy: 0.6148
# Epoch 2/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6313 - accuracy: 0.6342
# Epoch 3/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6258 - accuracy: 0.6371
# Epoch 4/10
# 160/160 [==============================] - 1s 6ms/step - loss: 0.6236 - accuracy: 0.6382
# Epoch 5/10
# 160/160 [==============================] - 1s 6ms/step - loss: 0.6222 - accuracy: 0.6382
# Epoch 6/10
# 160/160 [==============================] - 1s 6ms/step - loss: 0.6209 - accuracy: 0.6394
# Epoch 7/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6200 - accuracy: 0.6399
# Epoch 8/10
# 160/160 [==============================] - 1s 6ms/step - loss: 0.6197 - accuracy: 0.6400
# Epoch 9/10
# 160/160 [==============================] - 1s 6ms/step - loss: 0.6193 - accuracy: 0.6389
# Epoch 10/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6189 - accuracy: 0.6395
# 2022-06-30 14:35:27.467265: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: 3dmodels/interpolated_model_cont/assets

# %%
x_test[0]
# Out:
# array([0.00753585, 5.6130739 , 0.35807462])

# %%
# Model Classification Predictions
predictions = np.round(model(x_test).numpy())

# Separate Data into bins based on theta
theta_max = 2 * np.pi
theta_min = 0
epsilon = 0.5
bins = int((theta_max - theta_min) / (2 * epsilon))
var_list = np.arange(theta_min + epsilon, theta_max + epsilon, 2 * epsilon)

test_binned, x_test_bin, y_test_bin = [], [], []
for i in range(bins):
    c = var_list[i]
    test_binned.append(np.array([(x, t, y) for (x, t, y) in zip(x_test[:, 0], x_test[:, 1], y_test) if np.abs(t - c) < epsilon]))
    x_test_bin.append(np.array(test_binned[i][:, 0:2]))
    y_test_bin.append(np.array(test_binned[i][:, 2]))

# %%
fig, ax1 = plt.subplots(figsize=(10,10))
fontsize=16
minor_size=14

for i in range(bins):
    x_test = x_test_bin[i]
    y_test = y_test_bin[i]
    predictions = model(x_test).numpy()
    fpr, tpr, _ = sklearn.metrics.roc_curve(y_test, predictions)
    auc = sklearn.metrics.auc(fpr, tpr)
    ax1.plot(fpr, tpr, lw=2, label='Theta = %.1f, AUC = %.2f' % (var_list[i], auc))

ax1.plot([0, 1], [0, 1], '--', lw=2)
ax1.set_xlabel('False positive rate', fontsize=fontsize)
ax1.set_ylabel('True positive rate', fontsize=fontsize)
ax1.set_title('ROC curve', fontsize=fontsize)
ax1.legend()
ax1.tick_params(width=2, grid_alpha=0.5, labelsize=minor_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       6 x_test = x_test_bin[i]
#       7 y_test = y_test_bin[i]
# ----> 8 predictions = model(x_test).numpy()
#       9 fpr, tpr, _ = sklearn.metrics.roc_curve(y_test, predictions)
#      10 auc = sklearn.metrics.auc(fpr, tpr)
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py:1020, in Layer.__call__(self, *args, **kwargs)
#    1013 eager = tf.executing_eagerly()
#    1014 with call_context.enter(
#    1015     layer=self,
#    1016     inputs=inputs,
#    1017     build_graph=not eager,
#    1018     training=training_mode):
# -> 1020   input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1021   if eager:
#    1022     call_fn = self.call
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/input_spec.py:250, in assert_input_compatibility(input_spec, inputs, layer_name)
#     248       value = value.value
#     249     if value is not None and shape_as_list[int(axis)] not in {value, None}:
# --> 250       raise ValueError(
#     251           'Input ' + str(input_index) + ' of layer ' + layer_name + ' is'
#     252           ' incompatible with the layer: expected axis ' + str(axis) +
#     253           ' of input shape to have value ' + str(value) +
#     254           ' but received input with shape ' + display_shape(x.shape))
#     255 # Check shape.
#     256 if spec.shape is not None and shape.rank is not None:
#
# ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 3 but received input with shape (6218, 2)

# %% [markdown]
# # Training on just one Gaussian

# %%
theta_dat = 2.5 * np.ones(n)
x_train, x_test, y_train, y_test = theta_data(n, theta_dat)

model2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
]);

loss_fn = tf.keras.losses.BinaryCrossentropy()
model2.compile(
    optimizer='adam',
    loss=loss_fn,
    metrics=['accuracy']
)

batch_size = 1000

checkpoint_path = "tutorial/checkpoints/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    verbose=1,
    save_freq=10*batch_size
)

log_dir = "tutorial/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

EPOCHS=10
model2.fit(
    x_train, y_train, epochs=EPOCHS,
    batch_size=batch_size,
    callbacks=[cp_callback, tensorboard_callback]
);

model2.save('models/theta2.5')
# Out:
# 2022-06-16 12:03:41.884238: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-06-16 12:03:41.884311: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-06-16 12:03:41.885485: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# Epoch 1/10
#  22/160 [===>..........................] - ETA: 1s - loss: 0.6156 - accuracy: 0.6491
# 2022-06-16 12:03:43.273339: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-06-16 12:03:43.273373: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-06-16 12:03:43.301358: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-06-16 12:03:43.302871: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-06-16 12:03:43.315418: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43
#
# 2022-06-16 12:03:43.320934: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.trace.json.gz
# 2022-06-16 12:03:43.324856: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43
#
# 2022-06-16 12:03:43.329304: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.memory_profile.json.gz
# 2022-06-16 12:03:43.349191: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43
# Dumped tool data for xplane.pb to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.xplane.pb
# Dumped tool data for overview_page.pb to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.overview_page.pb
# Dumped tool data for input_pipeline.pb to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to tutorial/logs/20220616-120341/train/plugins/profile/2022_06_16_12_03_43/jupyter-matan.kernel_stats.pb
# 160/160 [==============================] - 2s 5ms/step - loss: 0.5769 - accuracy: 0.6894
# Epoch 2/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5698 - accuracy: 0.6948
# Epoch 3/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.5695 - accuracy: 0.6954
# Epoch 4/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5694 - accuracy: 0.6958
# Epoch 5/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.5691 - accuracy: 0.6963
# Epoch 6/10
# 160/160 [==============================] - 1s 5ms/step - loss: 0.5689 - accuracy: 0.6964
# Epoch 7/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5692 - accuracy: 0.6959
# Epoch 8/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5689 - accuracy: 0.6958
# Epoch 9/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5692 - accuracy: 0.6960
# Epoch 10/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5689 - accuracy: 0.6959
# INFO:tensorflow:Assets written to: models/theta2.5/assets

# %%
predictions2 = model2(x_test).numpy()
fpr, tpr, _ = sklearn.metrics.roc_curve(y_test, predictions2)
auc = sklearn.metrics.auc(fpr, tpr)
ax1.plot(fpr, tpr, lw=2, label='C = %.1f, AUC = %.2f' % (7, auc))
ax1.set_xlabel("Score")
fontsize=16
minor_size=14
fig, ax1 = plt.subplots(figsize=(6,6))
ax1.plot(fpr, tpr, lw=2)
ax1.set_xlabel('False positive rate', fontsize=fontsize)
ax1.set_ylabel('True positive rate', fontsize=fontsize)
ax1.set_title('Theta-2.5 Model ROC curve, Theta_data = %.1f, AUC = %.4f' % (theta_dat, auc), fontsize=fontsize)
ax1.tick_params(width=2, grid_alpha=0.5, labelsize=minor_size)

# %%
fpr, tpr, _ = sklearn.metrics.roc_curve(y_test, model(x_test).numpy())
auc = sklearn.metrics.auc(fpr, tpr)
ax1.plot(fpr, tpr, lw=2, label='C = %.1f, AUC = %.2f' % (7, auc))
ax1.set_xlabel("Score")
fontsize=16
minor_size=14
fig, ax1 = plt.subplots(figsize=(6,6))
ax1.plot(fpr, tpr, lw=2)
ax1.set_xlabel('False positive rate', fontsize=fontsize)
ax1.set_ylabel('True positive rate', fontsize=fontsize)
ax1.set_title('Interpolated Model ROC curve, Theta_data = %.1f, AUC = %.4f' % (theta_dat, auc), fontsize=fontsize)
ax1.tick_params(width=2, grid_alpha=0.5, labelsize=minor_size)

# %% [markdown]
# # Now let's try these both on a Gaussian with some random theta

# %%
theta0 = 4.3 * np.ones(n)
_, x_test0, _, y_test0 = theta_data(n, theta0)

# %%
# fig, ax1 = plt.subplots(figsize=(10,10))
# fontsize=16
# minor_size=14

predictions = model(x_test0).numpy()
fpr, tpr, _ = sklearn.metrics.roc_curve(y_test0, predictions)
auc = sklearn.metrics.auc(fpr, tpr)
ax1.plot(fpr, tpr, lw=2, label='C = %.1f, AUC = %.2f' % (7, auc))
ax1.set_xlabel("Score")
fontsize=16
minor_size=14
fig, ax1 = plt.subplots(figsize=(6,6))
ax1.plot(fpr, tpr, lw=2)
ax1.set_xlabel('False positive rate', fontsize=fontsize)
ax1.set_ylabel('True positive rate', fontsize=fontsize)
ax1.set_title('Interpolated Model ROC curve, Var_data = %.1f, AUC = %.6f' % (theta0, auc), fontsize=fontsize)
ax1.tick_params(width=2, grid_alpha=0.5, labelsize=minor_size)

predictions = model2(x_test0).numpy()
fpr, tpr, _ = sklearn.metrics.roc_curve(y_test0, predictions)
auc = sklearn.metrics.auc(fpr, tpr)
ax1.plot(fpr, tpr, lw=2, label='C = %.1f, AUC = %.6f' % (7, auc))
ax1.set_xlabel("Score")
fontsize=16
minor_size=14
fig, ax1 = plt.subplots(figsize=(6,6))
ax1.plot(fpr, tpr, lw=2)
ax1.set_xlabel('False positive rate', fontsize=fontsize)
ax1.set_ylabel('True positive rate', fontsize=fontsize)
ax1.set_title('Var-7.0 Model ROC curve, Var_data = %.1f, AUC = %.6f' % (theta0, auc), fontsize=fontsize)
ax1.tick_params(width=2, grid_alpha=0.5, labelsize=minor_size)
